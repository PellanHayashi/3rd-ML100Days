# %%
'''
請至以下機器學習巨頭的 blog 參觀，試著閱讀一篇文章並分析其 
作業 1：目標
Ans:
Personalized Hey Siri

作業 2：方法
Ans:
obtain more robust speaker-specific representations 
using a recurrent neural network, multi-style training, and curriculum learning.

作業 3：資料來源 
Ans:
"Hey Siri" users.
https://machinelearning.apple.com/2018/04/16/personalized-hey-siri.html
'''
# Out:
# '\n請至以下機器學習巨頭的 blog 參觀，試著閱讀一篇文章並分析其 \n作業 1：目標\nAns:\nPersonalized Hey Siri\n\n作業 2：方法\nAns:\nobtain more robust speaker-specific representations \nusing a recurrent neural network, multi-style training, and curriculum learning.\n\n作業 3：資料來源 \nAns:\n"Hey Siri" users.\nhttps://machinelearning.apple.com/2018/04/16/personalized-hey-siri.html\n'
